# %% [markdown]
# # WEEK-9 Programs & Practice

# %% [markdown]
# ## DATA ANALYSIS USING PANDAS

# %%
# CHECK pandas install or not
import pandas

# if no error after exections, pandas imported else not imported
#Youtube class practice

# %%
print(pandas.__version__) #Youtube Practice
# Out:
# 1.4.2

# %% [markdown]
# ### Workinig with DataFrames and series

# %%
#SKILL-LYNC
import pandas as pd

# %%
df1 = pd.DataFrame([['Marif',7,85],['Chandu',45,61],['Lokesh',43,79]])
df1
# Out:
#         0   1   2
# 0   Marif   7  85
# 1  Chandu  45  61
# 2  Lokesh  43  79

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# Adding Columns for data frames

df1 = pd.DataFrame([['Marif',7,85],['Chandu',45,61],['Lokesh',43,79]],columns = ['Student_Name','Roll_No','Percentage'])
df1
# Out:
#   Student_Name  Roll_No  Percentage
# 0        Marif        7          85
# 1       Chandu       45          61
# 2       Lokesh       43          79

# %%
#Adding row index names


df1 = pd.DataFrame([['Marif',7,85],['Chandu',45,61],['Lokesh',43,79]],
                   columns = ['Student_Name','Roll_No','Percentage'],
                   index = ['First_student','Second_student','Third_student'])
df1
# Out:
#                Student_Name  Roll_No  Percentage
# First_student         Marif        7          85
# Second_student       Chandu       45          61
# Third_student        Lokesh       43          79

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1.Student_Name)
# Out:
# pandas.core.series.Series

# %%
type(df1.Roll_No)
# Out:
# pandas.core.series.Series

# %%
type(df1.First_student)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 type(df1.First_student)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'First_student'

# %%
dir(df1)
# Out:
# ['Percentage',
#  'Roll_No',
#  'Student_Name',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df1
# Out:
#                Student_Name  Roll_No  Percentage
# First_student         Marif        7          85
# Second_student       Chandu       45          61
# Third_student        Lokesh       43          79

# %% [markdown]
# ### Applying Methods on DataFrames

# %%
# Mean value of all data in a DataFrame inseperate columns
df1.mean()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_5648\3532530860.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# Roll_No       31.666667
# Percentage    75.000000
# dtype: float64

# %%
# Mean value of all the numeric data
df1.mean().mean()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_5648\2749981327.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean().mean()
# 53.333333333333336

# %%
# Return the single column values

df1.Percentage

# OR 

df1['Percentage']
# Out:
# First_student     85
# Second_student    61
# Third_student     79
# Name: Percentage, dtype: int64

# %%
# Mean value of single column
df1.Percentage.mean()
# Out:
# 75.0

# %% [markdown]
# ### Creating a DataFrame from Dictionary

# %%
dict1 = {'First_Name':('Naveen Chand','Marif','Lokesh Babu','Venkata Sanjay Kumar'),
         'Last_Name':('GADDE','SHAIK','UPPUTURI','NEELI')}
df2 = pd.DataFrame(dict1)
df2
# Out:
#              First_Name Last_Name
# 0          Naveen Chand     GADDE
# 1                 Marif     SHAIK
# 2           Lokesh Babu  UPPUTURI
# 3  Venkata Sanjay Kumar     NEELI

# %%
# lIST OF DICTIONARIES 
l1 = [{'First_Name':'Naveen chand','Last_Name':'Gadde'},
      {'First_Name':'Marif','Last_Name':'Shaik'},
      {'First_Name':'Lokesh babu','Last_Name':'Upputuri'},
      {'First_Name':'Venkata sanjay kumar','Last_Name':'Neeli'}]
df3 = pd.DataFrame(l1)
df3
# Out:
#              First_Name Last_Name
# 0          Naveen chand     Gadde
# 1                 Marif     Shaik
# 2           Lokesh babu  Upputuri
# 3  Venkata sanjay kumar     Neeli

# %% [markdown]
# ## Loading Data from files into DataFrames
#
#
# ### ('.\Supermarkets.csv')  >> .\ represents the current workinng directory/path

# %%
df4 = pd.read_csv('.\Supermarkets.csv')    
df4
# Out:
#    ID          Address           City     State Country         Name  \
# 0   1     3666 21st st  San Francisco  CA 94114     USA      Madeira
# 1   2   735 Dolores st  San Francisco  CA 94114     USA  Bready Shop
# 2   3      332 Hill st  San Francisco  CA 94114     USA  Super River
# 3   4     3995 23rd st  San Francisco  CA 94114     USA   Ben's shop
# 4   5  1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez
# 5   6  551 Alvarado st  San Francisco  CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv('.\Supermarkets-commas.txt')
df5
# Out:
#    ID          Address           City     State Country         Name  \
# 0   1     3666 21st st  San Francisco  CA 94114     USA      Madeira
# 1   2   735 Dolores st  San Francisco  CA 94114     USA  Bready Shop
# 2   3      332 Hill st  San Francisco  CA 94114     USA  Super River
# 3   4     3995 23rd st  San Francisco  CA 94114     USA   Ben's shop
# 4   5  1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez
# 5   6  551 Alvarado st  San Francisco  CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pd.read_csv('.\supermarkets-semicolon.txt',sep=';')
df6
# Out:
#    ID          Address           City     State Country         Name  \
# 0   1     3666 21st st  San Francisco  CA 94114     USA      Madeira
# 1   2   735 Dolores st  San Francisco  CA 94114     USA  Bready Shop
# 2   3      332 Hill st  San Francisco  CA 94114     USA  Super River
# 3   4     3995 23rd st  San Francisco  CA 94114     USA   Ben's shop
# 4   5  1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez
# 5   6  551 Alvarado st  San Francisco  CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df4.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df7 = pd.read_json('.\iris.json')
df7
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
df8 = pd.read_excel('.\supermarkets.xlsx',sheet_name=0)
df8
# Out:
#    ID          Address           City     State Country         Name  \
# 0   1     3666 21st st  San Francisco  CA 94114     USA      Madeira
# 1   2   735 Dolores st  San Francisco  CA 94114     USA  Bready Shop
# 2   3      332 Hill st  San Francisco  CA 94114     USA  Super River
# 3   4     3995 23rd st  San Francisco  CA 94114     USA   Ben's shop
# 4   5  1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez
# 5   6  551 Alvarado st  San Francisco  CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df9 = pd.read_csv('.\data.txt',header=None)
df9
# Out:
#    0                1              2         3    4            5   6
# 0  1     3666 21st st  San Francisco  CA 94114  USA      Madeira   8
# 1  2   735 Dolores st  San Francisco  CA 94114  USA  Bready Shop  15
# 2  3      332 Hill st  San Francisco  CA 94114  USA  Super River  25
# 3  4     3995 23rd st  San Francisco  CA 94114  USA   Ben's shop  10
# 4  5  1056 Sanchez st  San Francisco  CA 94114  USA      Sanchez  12
# 5  6  551 Alvarado st  San Francisco  CA 94114  USA   Richvalley  20

# %%
# We can give user specified column names
df9.columns = ['ID','Address','City','Pin_code','Country','Shop_Name','Emplpoyees']

# %%
df9
# Out:
#    ID          Address           City  Pin_code Country    Shop_Name  \
# 0   1     3666 21st st  San Francisco  CA 94114     USA      Madeira
# 1   2   735 Dolores st  San Francisco  CA 94114     USA  Bready Shop
# 2   3      332 Hill st  San Francisco  CA 94114     USA  Super River
# 3   4     3995 23rd st  San Francisco  CA 94114     USA   Ben's shop
# 4   5  1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez
# 5   6  551 Alvarado st  San Francisco  CA 94114     USA   Richvalley
#
#    Emplpoyees
# 0           8
# 1          15
# 2          25
# 3          10
# 4          12
# 5          20

# %% [markdown]
# ## 4.Missing Data

# %%
#Here importing data and creating Header in code
df = pd.read_csv('.\marks.txt',header=None,names=["Name","S1","S2","S3"])
df
# Out:
#      Name    S1    S2     S3
# 0   Marif  90.0  89.0  100.0
# 1  Lokesh  88.0  92.0   95.0
# 2  Naveen  78.0  80.0   92.0
# 3  Sanjay   NaN  80.0    NaN
# 4  Mahesh  85.0   NaN   65.0
# 5   Usman   NaN   NaN    NaN

# %%
df.isnull()
# Out:
#     Name     S1     S2     S3
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False   True  False   True
# 4  False  False   True  False
# 5  False   True   True   True

# %%
df.notnull()
# Out:
#    Name     S1     S2     S3
# 0  True   True   True   True
# 1  True   True   True   True
# 2  True   True   True   True
# 3  True  False   True  False
# 4  True   True  False   True
# 5  True  False  False  False

# %%
df.notna()
# Out:
#    Name     S1     S2     S3
# 0  True   True   True   True
# 1  True   True   True   True
# 2  True   True   True   True
# 3  True  False   True  False
# 4  True   True  False   True
# 5  True  False  False  False

# %%
df_replaced = df.fillna('Absent')
df_replaced
# Out:
#      Name      S1      S2      S3
# 0   Marif    90.0    89.0   100.0
# 1  Lokesh    88.0    92.0    95.0
# 2  Naveen    78.0    80.0    92.0
# 3  Sanjay  Absent    80.0  Absent
# 4  Mahesh    85.0  Absent    65.0
# 5   Usman  Absent  Absent  Absent

# %%
df_replaced = df['S1'].fillna(df['S1'].mean())

# %%
df_replaced
# Out:
# 0    90.00
# 1    88.00
# 2    78.00
# 3    85.25
# 4    85.00
# 5    85.25
# Name: S1, dtype: float64

# %%
# Dropping the rows
df.dropna()
# Out:
#      Name    S1    S2     S3
# 0   Marif  90.0  89.0  100.0
# 1  Lokesh  88.0  92.0   95.0
# 2  Naveen  78.0  80.0   92.0

# %%
df.dropna(axis=1)
# Out:
#      Name
# 0   Marif
# 1  Lokesh
# 2  Naveen
# 3  Sanjay
# 4  Mahesh
# 5   Usman

# %%
df9
# Out:
#    ID          Address           City  Pin_code Country    Shop_Name  \
# 0   1     3666 21st st  San Francisco  CA 94114     USA      Madeira
# 1   2   735 Dolores st  San Francisco  CA 94114     USA  Bready Shop
# 2   3      332 Hill st  San Francisco  CA 94114     USA  Super River
# 3   4     3995 23rd st  San Francisco  CA 94114     USA   Ben's shop
# 4   5  1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez
# 5   6  551 Alvarado st  San Francisco  CA 94114     USA   Richvalley
#
#    Emplpoyees
# 0           8
# 1          15
# 2          25
# 3          10
# 4          12
# 5          20

# %%
df10 = df9.set_index('ID',inplace=True)
# WE RUN DOUBLE TIME WE GET THIS ERROR

# %%
df9
# Out:
#             Address           City  Pin_code Country    Shop_Name  Emplpoyees
# ID
# 1      3666 21st st  San Francisco  CA 94114     USA      Madeira           8
# 2    735 Dolores st  San Francisco  CA 94114     USA  Bready Shop          15
# 3       332 Hill st  San Francisco  CA 94114     USA  Super River          25
# 4      3995 23rd st  San Francisco  CA 94114     USA   Ben's shop          10
# 5   1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez          12
# 6   551 Alvarado st  San Francisco  CA 94114     USA   Richvalley          20

# %%
#LABLE BASED INDEXING
# Select all row and only country column

df9.loc[:,'Country']
# Out:
# ID
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# 6    USA
# Name: Country, dtype: object

# %%
df9.loc[2:5,'Country']
# Out:
# ID
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# Name: Country, dtype: object

# %%
# Select rows within index id 3 to 5 and columns city to Shop_Name


df9.loc[:,'City':'Shop_Name']
# Out:
#              City  Pin_code Country    Shop_Name
# ID
# 1   San Francisco  CA 94114     USA      Madeira
# 2   San Francisco  CA 94114     USA  Bready Shop
# 3   San Francisco  CA 94114     USA  Super River
# 4   San Francisco  CA 94114     USA   Ben's shop
# 5   San Francisco  CA 94114     USA      Sanchez
# 6   San Francisco  CA 94114     USA   Richvalley

# %%
# Integer based Indexing
# AN INTEGER returns the data from the 5th row

df9.iloc[:,4]
# Out:
# ID
# 1        Madeira
# 2    Bready Shop
# 3    Super River
# 4     Ben's shop
# 5        Sanchez
# 6     Richvalley
# Name: Shop_Name, dtype: object

# %%
df9
# Out:
#             Address           City  Pin_code Country    Shop_Name  Emplpoyees
# ID
# 1      3666 21st st  San Francisco  CA 94114     USA      Madeira           8
# 2    735 Dolores st  San Francisco  CA 94114     USA  Bready Shop          15
# 3       332 Hill st  San Francisco  CA 94114     USA  Super River          25
# 4      3995 23rd st  San Francisco  CA 94114     USA   Ben's shop          10
# 5   1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez          12
# 6   551 Alvarado st  San Francisco  CA 94114     USA   Richvalley          20

# %%
df9.iloc[4,5]
# Out:
# 12

# %%
df9.iloc[1:4,1:6]
# Out:
#              City  Pin_code Country    Shop_Name  Emplpoyees
# ID
# 2   San Francisco  CA 94114     USA  Bready Shop          15
# 3   San Francisco  CA 94114     USA  Super River          25
# 4   San Francisco  CA 94114     USA   Ben's shop          10

# %%
# Combination of integer and lable based indexing
df9.iloc[1:3,2:5]
# Out:
#     Pin_code Country    Shop_Name
# ID
# 2   CA 94114     USA  Bready Shop
# 3   CA 94114     USA  Super River

# %%
df9.iloc[1:5,:]
# Out:
#             Address           City  Pin_code Country    Shop_Name  Emplpoyees
# ID
# 2    735 Dolores st  San Francisco  CA 94114     USA  Bready Shop          15
# 3       332 Hill st  San Francisco  CA 94114     USA  Super River          25
# 4      3995 23rd st  San Francisco  CA 94114     USA   Ben's shop          10
# 5   1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez          12

# %%
df9
# Out:
#             Address           City  Pin_code Country    Shop_Name  Emplpoyees
# ID
# 1      3666 21st st  San Francisco  CA 94114     USA      Madeira           8
# 2    735 Dolores st  San Francisco  CA 94114     USA  Bready Shop          15
# 3       332 Hill st  San Francisco  CA 94114     USA  Super River          25
# 4      3995 23rd st  San Francisco  CA 94114     USA   Ben's shop          10
# 5   1056 Sanchez st  San Francisco  CA 94114     USA      Sanchez          12
# 6   551 Alvarado st  San Francisco  CA 94114     USA   Richvalley          20
